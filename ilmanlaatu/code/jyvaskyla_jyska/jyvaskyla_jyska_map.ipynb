# %%
import geopandas as gpd
import pandas as pd
from shapely import wkt

# %%
df = pd.read_csv("jyska_routes_2024-05-23.csv")
df['geometry'] = df['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(df, geometry='geometry', crs="EPSG:3067")

gdf = gdf.to_crs("EPSG:4326")
gdf = gdf[gdf.geometry.type == 'LineString']

# %%
from shapely.geometry import Point

def determine_value(row):
    if row['1000m'] and not row['500m'] and not row['100m']:
        return 1
    elif row['1000m'] and row['500m'] and not row['100m']:
        return 2
    elif row['1000m'] and row['500m'] and row['100m']:
        return 3
    else:
        return 0
    
gdf['value'] = gdf.apply(determine_value, axis=1)

point = Point(25.84843, 62.2415)

new_point_gdf = gpd.GeoDataFrame({'geometry': [point]}, crs=gdf.crs)
# new_point_gdf = new_point_gdf["geometry"].buffer(0.1)


# Concatenate the new GeoDataFrame with the original GeoDataFrame
frames = [gdf, new_point_gdf]

updated_gdf = pd.concat(frames, ignore_index=True)

# %%
updated_gdf.explore(column="value",cmap="viridis",marker_type="circle_marker", marker_kwds=dict(radius=10), style_kwds=dict(weight=2),tiles="CartoDB positron")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_950b57fc096535d62154c3c2568cfebe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_950b57fc096535d62154c3c2568cfebe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_950b57fc096535d62154c3c2568cfebe = L.map(
#                 &quot;map_950b57fc096535d62154c3c2568cfebe&quot;,
#                 {
#                     center: [62.2403675, 25.845448],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_950b57fc096535d62154c3c2568cfebe);
#
#
#
#
#
#             var tile_layer_5f8efa04c164979e17ae96ee6a38f2eb = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_950b57fc096535d62154c3c2568cfebe);
#
#
#             map_950b57fc096535d62154c3c2568cfebe.fitBounds(
#                 [[62.23216, 25.814346], [62.248574999999995, 25.87655]],
#                 {}
#             );
#
#
#         function geo_json_dd165442ba73269b23c817817ffa9a10_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;19&quot;: case &quot;23&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;43&quot;: case &quot;47&quot;: case &quot;50&quot;: case &quot;52&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;90&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;93&quot;: case &quot;97&quot;: case &quot;98&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;109&quot;: case &quot;110&quot;: case &quot;112&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;120&quot;: case &quot;121&quot;: case &quot;124&quot;: case &quot;125&quot;: case &quot;127&quot;: case &quot;128&quot;: case &quot;129&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;9&quot;: case &quot;17&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;25&quot;: case &quot;31&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;41&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;49&quot;: case &quot;99&quot;: case &quot;101&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;130&quot;:
#                     return {&quot;color&quot;: null, &quot;fillColor&quot;: null, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#21908d&quot;, &quot;fillColor&quot;: &quot;#21908d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_dd165442ba73269b23c817817ffa9a10_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_dd165442ba73269b23c817817ffa9a10_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
